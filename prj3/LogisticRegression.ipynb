# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from data import load_database_train
from preprocessing import InterpolateRawData
from train import grid_search, scikit_train_validate
from sklearn.model_selection import cross_val_score
from cross_validation import cv_folds_author
import numpy as np
from plotter import plot_all_readings


# %matplotlib inline

# %%
database_train = load_database_train()
X_processed = InterpolateRawData(num_samples=40).fit_transform(database_train.X)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## Comparação entre 2 algoritmos: sag vs liblinear

# %% [markdown]
# ### Algoritmo sag

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [10, 100, 200, 300],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:    4.9s
# ...

# %% [markdown]
# ### Algoritmo liblinear

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [10, 100, 200, 300],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['liblinear'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:    5.6s
# ...

# %% [markdown]
# ## Comparação entre 3 valores de máximo de iterações

# %% [markdown]
# ### Max_iter 10

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [10],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done  12 out of  20 | elapsed:    0.6s remaining:    0.4s
# [Parallel(n_jobs=6)]: Done  15 out of  20 | elapsed:    0.8s remaining:    0.3s
# ...

# %% [markdown]
# ### Max_iter 50

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [50],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done  12 out of  20 | elapsed:    1.7s remaining:    1.1s
# [Parallel(n_jobs=6)]: Done  15 out of  20 | elapsed:    2.0s remaining:    0.7s
# ...

# %% [markdown]
# ### Max_iter 100

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [100],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=6)]: Done  12 out of  20 | elapsed:    2.9s remaining:    1.9s
# [Parallel(n_jobs=6)]: Done  15 out of  20 | elapsed:    3.8s remaining:    1.3s
# ...

# %% [markdown]
# ## Comparação entre ter ou não um fit_intercept

# %% [markdown]
# ### fit_intercept = True

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': ['balanced'],
    'logisticRegression__fit_intercept': [True],
    'logisticRegression__max_iter': [50],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done  12 out of  20 | elapsed:    1.7s remaining:    1.1s
# [Parallel(n_jobs=6)]: Done  15 out of  20 | elapsed:    2.2s remaining:    0.7s
# ...

# %% [markdown]
# ## Sem pesos nas classes

# %% [markdown]
# ### class_weight = None

# %%
pipe = Pipeline([
    ('logisticRegression', LogisticRegression())
])

print(pipe.get_params().keys())

parameters = {
    'logisticRegression__C': [1, 1.5, 2, 2.5],
    'logisticRegression__class_weight': [None],
    'logisticRegression__fit_intercept': [False],
    'logisticRegression__max_iter': [10],
    'logisticRegression__n_jobs': [5],
    'logisticRegression__solver': ['sag'],
    'logisticRegression__warm_start': [True]
}
grid_search(pipe, parameters, X_processed, database_train.y, database_train.cv_author, n_jobs=6)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'logisticRegression', 'logisticRegression__C', 'logisticRegression__class_weight', 'logisticRegression__dual', 'logisticRegression__fit_intercept', 'logisticRegression__intercept_scaling', 'logisticRegression__l1_ratio', 'logisticRegression__max_iter', 'logisticRegression__multi_class', 'logisticRegression__n_jobs', 'logisticRegression__penalty', 'logisticRegression__random_state', 'logisticRegression__solver', 'logisticRegression__tol', 'logisticRegression__verbose', 'logisticRegression__warm_start'])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done  12 out of  20 | elapsed:    0.6s remaining:    0.4s
# [Parallel(n_jobs=6)]: Done  15 out of  20 | elapsed:    0.7s remaining:    0.2s
# ...
