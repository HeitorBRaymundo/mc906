# %%
import pandas as pd
from data import load_database
from preprocessing import correct_timestamp

database = pd.DataFrame(data=load_database())
readings = database['readings'][0]
correct_timestamp(readings)
readings = readings.transpose()

index = readings[0]

for i in range(1, len(readings)):
    data = {str(i): readings[i]}
    df = pd.DataFrame(data, index=index)
    df.plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:304: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
