# %% [markdown]
# # Jigsaw Puzzle Solver utilizando Algoritmos Genéticos
# ## Integrantes do Grupo
# 146318 Guilherme Rodrigues Bueno
#
# 146388 Heitor Banhete Raymundo
#
# 163993 Anderson Nogueira Cotrim
#
# 166597	Diego Yutaka Kamiha
#
# 188802 Yuri Luiz de Oliveira
#
# ## Definição do problema
#
#
#
#
# ## Implementação e modelo evolucionário adotado
#
#
#
# ### Fitness function
#
#
# ### Variações nos parâmetros

# %%
from genetic_algorithm import exp_genetic_algorithm
from puzzle import Puzzle

# %% [markdown]
# # Experimentos tamanho da população X tamanho do problema

# %%
exp_genetic_algorithm('imgs/star-wars.jpg', (4, 4), 
                      pop_size=1000, max_iterations=1000, mutation='swap_pieces', crossover='random_split')
# Out:
# Número de combinações possíveis: 20922789888000
# Iteração atual 555: 9 - 46.382 - 59 (min - media - max))
# Tempo de execução: 186.827312707901s
# Generating video...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-e4a4c09d5e0d> in <module>
#       1 exp_genetic_algorithm('imgs/star-wars.jpg', (4, 4),
# ----> 2                       pop_size=1000, max_iterations=1000, mutation='swap_pieces', crossover='random_split')
#
# ~/src/unicamp/mc906/prj2/genetic_algorithm.py in exp_genetic_algorithm(puzzle_file, puzzle_splits, pop_size, fitness, selection, crossover, mutation, replace, selection_count, selection_tournament_size, crossover_rate, mutation_rate, mutation_swapness, replacement_rate, max_iterations, report_time)
#      47     ga.statistics.plot()
#      48     print("Generating video... ")
# ---> 49     animation.show_video()
#      50     print("Finished")
#      51
#
# ~/src/unicamp/mc906/prj2/utils.py in show_video(self)
#      69         anim = animation.FuncAnimation(self.fig, self._animate, frames=len(self.frames), interval=500, blit=True)
#      70         plt.close()
# ---> 71         display(HTML(anim.to_html5_video()))
#      72         self._remove_last_frames()
#      73
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1326                 # We create a writer manually so that we can get the
#    1327                 # appropriate size for the tag
# -> 1328                 Writer = writers[rcParams['animation.writer']]
#    1329                 writer = Writer(codec='h264',
#    1330                                 bitrate=rcParams['animation.bitrate'],
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     162         if self.is_available(name):
#     163             return self._registered[name]
# --> 164         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     165
#     166
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
exp_genetic_algorithm('imgs/star-wars.jpg', (4, 4), 
                      pop_size=1000, max_iterations=1000, mutation='swap_pieces', crossover='random_split')
